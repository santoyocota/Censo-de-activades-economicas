# %%
def eliminar_separador_final_de_datos(filas_datos, separador):
    # Recorre cada fila de datos desde la segunda fila en adelante (debajo del header)
    nuevas_filas = []
    for fila in filas_datos:
        # Si la fila tiene el separador al final, lo eliminamos
        if fila.endswith(separador):
            fila = fila.rstrip(separador)
        nuevas_filas.append(fila)
    return nuevas_filas

def ajustar_columnas(ruta_archivo, separador):
    ajustes_realizados = True

    while ajustes_realizados:
        try:
            with open(ruta_archivo, 'r', encoding='utf-8') as archivo:
                # Leer la primera fila (header) y todas las filas de datos
                primera_fila = archivo.readline().strip()  # Header
                filas_datos = archivo.readlines()  # Datos
                filas_datos = [fila.strip() for fila in filas_datos]  # Limpiar espacios en blanco

            # Separar el header y la primera fila de datos utilizando el separador
            columnas_header = primera_fila.split(separador)
            columnas_datos = filas_datos[0].split(separador)

            # Contar las columnas del header y de los datos
            num_columnas_header = len(columnas_header)
            num_columnas_datos = len(columnas_datos)

            # Mostrar el conteo de columnas
            print(f"Columnas en el encabezado: {num_columnas_header}")
            print(f"Columnas en los datos: {num_columnas_datos}")

            ajustes_realizados = False  # Inicializamos la variable en False

            # Caso 1: El header termina con el separador
            if primera_fila.endswith(separador):
                print("Caso: El header termina con el separador.")
                nueva_primera_fila = eliminar_separador_final(primera_fila, separador)
                primera_fila = nueva_primera_fila  # Actualizamos el header
                ajustes_realizados = True  # Indicamos que se ha realizado un ajuste

            # Caso 2: El header tiene una columna más que los datos
            elif num_columnas_header - num_columnas_datos == 1:
                print("Caso: El header tiene una columna más que los datos.")
                if not primera_fila.endswith(separador):
                    # Agregar separador al final de cada fila de datos
                    filas_datos = agregar_separador_final_a_datos(filas_datos, separador)
                    print("Se ha agregado un separador al final de cada fila de datos.")
                    ajustes_realizados = True  # Indicamos que se ha realizado un ajuste

            # Caso 3: Los datos tienen una columna más que el header
            elif num_columnas_datos - num_columnas_header == 1:
                print("Caso: Los datos tienen una columna más que el header.")
                # Eliminar separador al final de cada fila de datos si está presente
                filas_datos = eliminar_separador_final_de_datos(filas_datos, separador)
                print("Se ha eliminado el separador al final de cada fila de datos.")
                ajustes_realizados = True  # Indicamos que se ha realizado un ajuste

            # Guardar los cambios en el archivo original
            with open(ruta_archivo, 'w', encoding='utf-8') as archivo:
                archivo.write(primera_fila + '\n')  # Guardar el header
                archivo.write('\n'.join(filas_datos) + '\n')  # Guardar las filas de datos

            if ajustes_realizados:
                print("Se ha realizado un ajuste, volviendo a validar...")
            else:
                print("El archivo está correctamente ajustado.")

        except Exception as e:
            print(f"Error al procesar el archivo: {e}")
            break

# %%
# Ejemplo de uso:
ruta_archivo = 'datasets/ce2019_bc.csv'
separador = ','  # Define el separador del archivo CSV
ajustar_columnas(ruta_archivo, separador)
# Out:
# Columnas en el encabezado: 186
# Columnas en los datos: 187
# Caso: Los datos tienen una columna más que el header.
# Se ha eliminado el separador al final de cada fila de datos.
# Se ha realizado un ajuste, volviendo a validar...
# Columnas en el encabezado: 186
# Columnas en los datos: 186
# El archivo está correctamente ajustado.

# %%
def validar_columnas_datos(ruta_archivo, separador, num_ajustes):
    try:
        with open(ruta_archivo, 'r', encoding='utf-8') as archivo:
            # Leer la primera fila (header) y todas las filas de datos
            primera_fila = archivo.readline().strip()  # Header
            filas_datos = archivo.readlines()  # Datos
            filas_datos = [fila.strip() for fila in filas_datos]  # Limpiar espacios en blanco

        # Contar la cantidad de columnas del header
        columnas_header = primera_fila.split(separador)
        num_columnas_header = len(columnas_header)
        print(f"Cantidad de columnas en el encabezado: {num_columnas_header}")

        # Validar las columnas en los datos
        inconsistencias = []  # Para guardar las filas con cantidad de columnas distintas
        conteo_columnas = {}  # Diccionario para contar cuántas filas tienen cada número de columnas
        filas_ajustadas = []  # Guardar las filas ya ajustadas

        # Contador de ajustes realizados
        ajustes_realizados = 0

        for i, fila in enumerate(filas_datos, start=2):  # Comenzamos en la línea 2 (debajo del header)
            columnas_fila = fila.split(separador)
            num_columnas_fila = len(columnas_fila)

            # Contar cuántas veces aparece un número específico de columnas
            if num_columnas_fila in conteo_columnas:
                conteo_columnas[num_columnas_fila] += 1
            else:
                conteo_columnas[num_columnas_fila] = 1

            # Registrar si hay diferencias con respecto al header
            if num_columnas_fila != num_columnas_header:
                inconsistencias.append((i, num_columnas_fila))  # Guardar el número de línea y número de columnas
            filas_ajustadas.append(columnas_fila)

        # Cálculo del promedio de columnas en las filas
        promedio_columnas = sum([len(fila.split(separador)) for fila in filas_datos]) / len(filas_datos)

        # Revisar si se necesita realizar algún ajuste
        if len(inconsistencias) <= num_ajustes:
            for i, (linea, num_columnas_fila) in enumerate(inconsistencias):
                # Caso donde hay una columna más en la fila de datos
                if num_columnas_fila == num_columnas_header + 1:
                    # Eliminar el separador al final si está presente
                    if filas_datos[linea - 2].endswith(separador):  # Revisamos las filas sin contar el header
                        filas_datos[linea - 2] = filas_datos[linea - 2].rstrip(separador)
                        ajustes_realizados += 1

                # Caso donde hay una columna menos en la fila de datos
                elif num_columnas_fila == num_columnas_header - 1:
                    # Añadir un separador al final si el promedio de columnas es mayor
                    if len(columnas_fila) < promedio_columnas:
                        filas_datos[linea - 2] += separador
                        ajustes_realizados += 1

        # Guardar los cambios en el archivo original
        with open(ruta_archivo, 'w', encoding='utf-8') as archivo:
            archivo.write(primera_fila + '\n')  # Escribir el header
            archivo.writelines(fila + '\n' for fila in filas_datos)  # Escribir las filas ajustadas

        # Mostrar reporte
        print("=== Reporte de validación de columnas ===")
        print(f"El archivo contiene {len(filas_datos)} filas de datos.")
        if len(conteo_columnas) == 1:
            print(f"Todas las filas tienen la misma cantidad de columnas: {num_columnas_header}.")
        else:
            print("Se encontraron diferencias en la cantidad de columnas entre los registros:")
            for num_columnas, cantidad in conteo_columnas.items():
                print(f" - {cantidad} filas tienen {num_columnas} columnas.")

            # Mostrar detalles de las inconsistencias
            if inconsistencias:
                print("\n=== Inconsistencias detectadas ===")
                for (linea, num_columnas_fila) in inconsistencias:
                    print(f" - Línea {linea}: tiene {num_columnas_fila} columnas.")
                print(f"Se realizaron {ajustes_realizados} ajustes.")

        print("=== Fin del reporte ===")
        
    except Exception as e:
        print(f"Error al procesar el archivo: {e}")

# Ejemplo de uso:
ruta_archivo = 'datasets/tc_codigo_actividad.csv'
separador = ','  # Define el separador del archivo CSV
num_ajustes = 5  # Número de ajustes permitidos

# Primero ajustar las columnas
ajustar_columnas(ruta_archivo, separador)


# Después validar las columnas de los datos
validar_columnas_datos(ruta_archivo, separador, num_ajustes)
# Out:
# Columnas en el encabezado: 3
# Columnas en los datos: 4
# Caso: Los datos tienen una columna más que el header.
# Se ha eliminado el separador al final de cada fila de datos.
# Se ha realizado un ajuste, volviendo a validar...
# Columnas en el encabezado: 3
# Columnas en los datos: 3
# El archivo está correctamente ajustado.
# Cantidad de columnas en el encabezado: 3
# === Reporte de validación de columnas ===
# El archivo contiene 1847 filas de datos.
# Se encontraron diferencias en la cantidad de columnas entre los registros:
#  - 1522 filas tienen 3 columnas.
#  - 18 filas tienen 6 columnas.
#  - 231 filas tienen 4 columnas.
#  - 71 filas tienen 5 columnas.
#  - 5 filas tienen 7 columnas.
#
# === Inconsistencias detectadas ===
#  - Línea 3: tiene 6 columnas.
#  - Línea 8: tiene 4 columnas.
#  - Línea 9: tiene 4 columnas.
#  - Línea 15: tiene 5 columnas.
#  - Línea 34: tiene 4 columnas.
#  - Línea 44: tiene 4 columnas.
#  - Línea 52: tiene 4 columnas.
#  - Línea 56: tiene 7 columnas.
#  - Línea 78: tiene 6 columnas.
#  - Línea 79: tiene 6 columnas.
#  - Línea 80: tiene 5 columnas.
#  - Línea 87: tiene 4 columnas.
#  - Línea 94: tiene 4 columnas.
#  - Línea 95: tiene 4 columnas.
#  - Línea 96: tiene 4 columnas.
#  - Línea 97: tiene 4 columnas.
#  - Línea 107: tiene 4 columnas.
#  - Línea 110: tiene 4 columnas.
#  - Línea 113: tiene 6 columnas.
#  - Línea 114: tiene 5 columnas.
#  - Línea 115: tiene 4 columnas.
#  - Línea 117: tiene 5 columnas.
#  - Línea 134: tiene 4 columnas.
#  - Línea 139: tiene 4 columnas.
#  - Línea 144: tiene 4 columnas.
#  - Línea 157: tiene 5 columnas.
#  - Línea 163: tiene 4 columnas.
#  - Línea 165: tiene 4 columnas.
#  - Línea 187: tiene 5 columnas.
#  - Línea 193: tiene 4 columnas.
#  - Línea 198: tiene 5 columnas.
#  - Línea 202: tiene 4 columnas.
#  - Línea 203: tiene 4 columnas.
#  - Línea 206: tiene 5 columnas.
#  - Línea 207: tiene 5 columnas.
#  - Línea 210: tiene 5 columnas.
#  - Línea 217: tiene 4 columnas.
#  - Línea 221: tiene 5 columnas.
#  - Línea 222: tiene 5 columnas.
#  - Línea 223: tiene 4 columnas.
#  - Línea 224: tiene 4 columnas.
#  - Línea 225: tiene 4 columnas.
#  - Línea 247: tiene 5 columnas.
#  - Línea 248: tiene 5 columnas.
#  - Línea 258: tiene 5 columnas.
#  - Línea 264: tiene 4 columnas.
#  - Línea 268: tiene 4 columnas.
#  - Línea 280: tiene 4 columnas.
#  - Línea 281: tiene 4 columnas.
#  - Línea 299: tiene 4 columnas.
#  - Línea 300: tiene 4 columnas.
#  - Línea 303: tiene 4 columnas.
#  - Línea 304: tiene 4 columnas.
#  - Línea 305: tiene 4 columnas.
#  - Línea 310: tiene 4 columnas.
#  - Línea 322: tiene 4 columnas.
#  - Línea 323: tiene 4 columnas.
#  - Línea 335: tiene 5 columnas.
#  - Línea 346: tiene 4 columnas.
#  - Línea 347: tiene 4 columnas.
#  - Línea 348: tiene 4 columnas.
#  - Línea 349: tiene 4 columnas.
#  - Línea 364: tiene 4 columnas.
#  - Línea 365: tiene 4 columnas.
#  - Línea 370: tiene 4 columnas.
#  - Línea 392: tiene 4 columnas.
#  - Línea 417: tiene 4 columnas.
#  - Línea 423: tiene 4 columnas.
#  - Línea 426: tiene 4 columnas.
#  - Línea 427: tiene 4 columnas.
#  - Línea 432: tiene 4 columnas.
#  - Línea 437: tiene 4 columnas.
#  - Línea 438: tiene 4 columnas.
#  - Línea 439: tiene 4 columnas.
#  - Línea 440: tiene 4 columnas.
#  - Línea 441: tiene 4 columnas.
#  - Línea 449: tiene 4 columnas.
#  - Línea 456: tiene 4 columnas.
#  - Línea 457: tiene 4 columnas.
#  - Línea 483: tiene 5 columnas.
#  - Línea 484: tiene 4 columnas.
#  - Línea 509: tiene 4 columnas.
#  - Línea 533: tiene 4 columnas.
#  - Línea 534: tiene 4 columnas.
#  - Línea 560: tiene 4 columnas.
#  - Línea 570: tiene 4 columnas.
#  - Línea 571: tiene 4 columnas.
#  - Línea 572: tiene 4 columnas.
#  - Línea 576: tiene 5 columnas.
#  - Línea 577: tiene 5 columnas.
#  - Línea 588: tiene 4 columnas.
#  - Línea 596: tiene 4 columnas.
#  - Línea 597: tiene 4 columnas.
#  - Línea 610: tiene 5 columnas.
#  - Línea 611: tiene 5 columnas.
#  - Línea 617: tiene 4 columnas.
#  - Línea 618: tiene 4 columnas.
#  - Línea 619: tiene 4 columnas.
#  - Línea 630: tiene 6 columnas.
#  - Línea 637: tiene 4 columnas.
#  - Línea 638: tiene 4 columnas.
#  - Línea 647: tiene 6 columnas.
#  - Línea 648: tiene 6 columnas.
#  - Línea 650: tiene 6 columnas.
#  - Línea 654: tiene 4 columnas.
#  - Línea 674: tiene 5 columnas.
#  - Línea 675: tiene 5 columnas.
#  - Línea 719: tiene 4 columnas.
#  - Línea 720: tiene 4 columnas.
#  - Línea 723: tiene 5 columnas.
#  - Línea 724: tiene 5 columnas.
#  - Línea 728: tiene 4 columnas.
#  - Línea 734: tiene 5 columnas.
#  - Línea 735: tiene 5 columnas.
#  - Línea 736: tiene 4 columnas.
#  - Línea 749: tiene 5 columnas.
#  - Línea 750: tiene 5 columnas.
#  - Línea 755: tiene 4 columnas.
#  - Línea 756: tiene 4 columnas.
#  - Línea 761: tiene 6 columnas.
#  - Línea 773: tiene 4 columnas.
#  - Línea 774: tiene 4 columnas.
#  - Línea 787: tiene 4 columnas.
#  - Línea 792: tiene 4 columnas.
#  - Línea 793: tiene 4 columnas.
#  - Línea 796: tiene 4 columnas.
#  - Línea 797: tiene 4 columnas.
#  - Línea 801: tiene 4 columnas.
#  - Línea 802: tiene 4 columnas.
#  - Línea 805: tiene 6 columnas.
#  - Línea 809: tiene 4 columnas.
#  - Línea 814: tiene 4 columnas.
#  - Línea 815: tiene 4 columnas.
#  - Línea 819: tiene 5 columnas.
#  - Línea 829: tiene 5 columnas.
#  - Línea 832: tiene 4 columnas.
#  - Línea 833: tiene 4 columnas.
#  - Línea 835: tiene 4 columnas.
#  - Línea 836: tiene 4 columnas.
#  - Línea 837: tiene 4 columnas.
#  - Línea 841: tiene 4 columnas.
#  - Línea 859: tiene 7 columnas.
#  - Línea 860: tiene 4 columnas.
#  - Línea 861: tiene 4 columnas.
#  - Línea 862: tiene 4 columnas.
#  - Línea 870: tiene 4 columnas.
#  - Línea 872: tiene 4 columnas.
#  - Línea 874: tiene 4 columnas.
#  - Línea 875: tiene 4 columnas.
#  - Línea 876: tiene 5 columnas.
#  - Línea 879: tiene 4 columnas.
#  - Línea 880: tiene 4 columnas.
#  - Línea 881: tiene 4 columnas.
#  - Línea 883: tiene 4 columnas.
#  - Línea 885: tiene 4 columnas.
#  - Línea 886: tiene 4 columnas.
#  - Línea 887: tiene 4 columnas.
#  - Línea 888: tiene 5 columnas.
#  - Línea 889: tiene 4 columnas.
#  - Línea 894: tiene 6 columnas.
#  - Línea 896: tiene 4 columnas.
#  - Línea 897: tiene 4 columnas.
#  - Línea 904: tiene 4 columnas.
#  - Línea 905: tiene 4 columnas.
#  - Línea 906: tiene 4 columnas.
#  - Línea 907: tiene 4 columnas.
#  - Línea 914: tiene 4 columnas.
#  - Línea 919: tiene 4 columnas.
#  - Línea 920: tiene 4 columnas.
#  - Línea 929: tiene 5 columnas.
#  - Línea 930: tiene 4 columnas.
#  - Línea 931: tiene 4 columnas.
#  - Línea 935: tiene 4 columnas.
#  - Línea 936: tiene 4 columnas.
#  - Línea 937: tiene 4 columnas.
#  - Línea 940: tiene 4 columnas.
#  - Línea 953: tiene 4 columnas.
#  - Línea 957: tiene 4 columnas.
#  - Línea 970: tiene 5 columnas.
#  - Línea 971: tiene 5 columnas.
#  - Línea 975: tiene 7 columnas.
#  - Línea 976: tiene 7 columnas.
#  - Línea 983: tiene 5 columnas.
#  - Línea 989: tiene 4 columnas.
#  - Línea 990: tiene 5 columnas.
#  - Línea 991: tiene 5 columnas.
#  - Línea 992: tiene 4 columnas.
#  - Línea 996: tiene 5 columnas.
#  - Línea 1004: tiene 4 columnas.
#  - Línea 1005: tiene 4 columnas.
#  - Línea 1006: tiene 4 columnas.
#  - Línea 1014: tiene 5 columnas.
#  - Línea 1019: tiene 4 columnas.
#  - Línea 1020: tiene 4 columnas.
#  - Línea 1021: tiene 4 columnas.
#  - Línea 1022: tiene 4 columnas.
#  - Línea 1023: tiene 4 columnas.
#  - Línea 1028: tiene 4 columnas.
#  - Línea 1035: tiene 4 columnas.
#  - Línea 1036: tiene 4 columnas.
#  - Línea 1037: tiene 5 columnas.
#  - Línea 1038: tiene 5 columnas.
#  - Línea 1039: tiene 5 columnas.
#  - Línea 1040: tiene 5 columnas.
#  - Línea 1041: tiene 4 columnas.
#  - Línea 1057: tiene 4 columnas.
#  - Línea 1058: tiene 4 columnas.
#  - Línea 1074: tiene 4 columnas.
#  - Línea 1080: tiene 4 columnas.
#  - Línea 1086: tiene 4 columnas.
#  - Línea 1118: tiene 4 columnas.
#  - Línea 1119: tiene 4 columnas.
#  - Línea 1154: tiene 4 columnas.
#  - Línea 1186: tiene 7 columnas.
#  - Línea 1187: tiene 6 columnas.
#  - Línea 1197: tiene 4 columnas.
#  - Línea 1206: tiene 4 columnas.
#  - Línea 1208: tiene 4 columnas.
#  - Línea 1211: tiene 4 columnas.
#  - Línea 1247: tiene 4 columnas.
#  - Línea 1248: tiene 4 columnas.
#  - Línea 1249: tiene 4 columnas.
#  - Línea 1250: tiene 4 columnas.
#  - Línea 1295: tiene 4 columnas.
#  - Línea 1296: tiene 4 columnas.
#  - Línea 1310: tiene 5 columnas.
#  - Línea 1318: tiene 4 columnas.
#  - Línea 1319: tiene 4 columnas.
#  - Línea 1320: tiene 4 columnas.
#  - Línea 1331: tiene 5 columnas.
#  - Línea 1342: tiene 4 columnas.
#  - Línea 1345: tiene 5 columnas.
#  - Línea 1347: tiene 4 columnas.
#  - Línea 1353: tiene 5 columnas.
#  - Línea 1358: tiene 6 columnas.
#  - Línea 1359: tiene 6 columnas.
#  - Línea 1360: tiene 4 columnas.
#  - Línea 1361: tiene 4 columnas.
#  - Línea 1364: tiene 6 columnas.
#  - Línea 1365: tiene 4 columnas.
#  - Línea 1366: tiene 4 columnas.
#  - Línea 1368: tiene 4 columnas.
#  - Línea 1369: tiene 4 columnas.
#  - Línea 1370: tiene 4 columnas.
#  - Línea 1371: tiene 4 columnas.
#  - Línea 1372: tiene 4 columnas.
#  - Línea 1373: tiene 4 columnas.
#  - Línea 1381: tiene 4 columnas.
#  - Línea 1382: tiene 4 columnas.
#  - Línea 1385: tiene 4 columnas.
#  - Línea 1414: tiene 4 columnas.
#  - Línea 1422: tiene 5 columnas.
#  - Línea 1423: tiene 6 columnas.
#  - Línea 1425: tiene 4 columnas.
#  - Línea 1443: tiene 4 columnas.
#  - Línea 1453: tiene 4 columnas.
#  - Línea 1454: tiene 4 columnas.
#  - Línea 1461: tiene 4 columnas.
#  - Línea 1476: tiene 6 columnas.
#  - Línea 1479: tiene 4 columnas.
#  - Línea 1482: tiene 5 columnas.
#  - Línea 1483: tiene 4 columnas.
#  - Línea 1498: tiene 4 columnas.
#  - Línea 1499: tiene 4 columnas.
#  - Línea 1500: tiene 4 columnas.
#  - Línea 1510: tiene 4 columnas.
#  - Línea 1511: tiene 4 columnas.
#  - Línea 1532: tiene 5 columnas.
#  - Línea 1541: tiene 4 columnas.
#  - Línea 1564: tiene 4 columnas.
#  - Línea 1604: tiene 4 columnas.
#  - Línea 1605: tiene 4 columnas.
#  - Línea 1622: tiene 4 columnas.
#  - Línea 1625: tiene 4 columnas.
#  - Línea 1626: tiene 4 columnas.
#  - Línea 1638: tiene 5 columnas.
#  - Línea 1639: tiene 5 columnas.
#  - Línea 1640: tiene 5 columnas.
#  - Línea 1641: tiene 4 columnas.
#  - Línea 1661: tiene 4 columnas.
#  - Línea 1668: tiene 4 columnas.
#  - Línea 1669: tiene 4 columnas.
#  - Línea 1670: tiene 4 columnas.
#  - Línea 1674: tiene 4 columnas.
#  - Línea 1675: tiene 5 columnas.
#  - Línea 1689: tiene 5 columnas.
#  - Línea 1690: tiene 5 columnas.
#  - Línea 1691: tiene 5 columnas.
#  - Línea 1692: tiene 5 columnas.
#  - Línea 1693: tiene 5 columnas.
#  - Línea 1694: tiene 4 columnas.
#  - Línea 1695: tiene 4 columnas.
#  - Línea 1696: tiene 4 columnas.
#  - Línea 1697: tiene 4 columnas.
#  - Línea 1698: tiene 4 columnas.
#  - Línea 1699: tiene 4 columnas.
#  - Línea 1700: tiene 5 columnas.
#  - Línea 1701: tiene 5 columnas.
#  - Línea 1708: tiene 4 columnas.
#  - Línea 1709: tiene 4 columnas.
#  - Línea 1717: tiene 4 columnas.
#  - Línea 1719: tiene 4 columnas.
#  - Línea 1737: tiene 4 columnas.
#  - Línea 1738: tiene 4 columnas.
#  - Línea 1742: tiene 4 columnas.
#  - Línea 1743: tiene 4 columnas.
#  - Línea 1747: tiene 4 columnas.
#  - Línea 1748: tiene 4 columnas.
#  - Línea 1757: tiene 5 columnas.
#  - Línea 1758: tiene 5 columnas.
#  - Línea 1759: tiene 4 columnas.
#  - Línea 1760: tiene 4 columnas.
#  - Línea 1767: tiene 6 columnas.
#  - Línea 1769: tiene 5 columnas.
#  - Línea 1783: tiene 4 columnas.
#  - Línea 1796: tiene 5 columnas.
#  - Línea 1797: tiene 5 columnas.
#  - Línea 1800: tiene 4 columnas.
#  - Línea 1806: tiene 4 columnas.
#  - Línea 1813: tiene 4 columnas.
#  - Línea 1817: tiene 4 columnas.
#  - Línea 1837: tiene 5 columnas.
#  - Línea 1838: tiene 5 columnas.
#  - Línea 1839: tiene 5 columnas.
#  - Línea 1846: tiene 4 columnas.
# Se realizaron 0 ajustes.
# === Fin del reporte ===

# %% [markdown]
# # cambiar delimitadores con caso especial

# %%
import csv
import re

def cambiar_delimitadores(input_file, output_file):
    with open(input_file, mode='r', encoding='utf-8') as infile, open(output_file, mode='w', encoding='utf-8', newline='') as outfile:
        reader = csv.reader(infile)
        writer = csv.writer(outfile, delimiter=',', quoting=csv.QUOTE_MINIMAL)

        for row in reader:
            nueva_fila = []
            for celda in row:
                # Si la celda está entre comillas dobles, no se modifica
                if re.match(r'^".*"$', celda):
                    nueva_fila.append(celda)
                else:
                    # Reemplazar las comas por comillas simples en celdas normales
                    nueva_fila.append(celda.replace(',', "._"))
            writer.writerow(nueva_fila)

# Ejemplo de uso

#diccionario_de_datos_ce2019
#tc_codigo_actividad
input_csv = 'datasets/tc_codigo_actividad.csv'  # Archivo CSV original
output_csv = 'datasets/tc_codigo_actividad_new.csv'  # Archivo CSV modificado
cambiar_delimitadores(input_csv, output_csv)
